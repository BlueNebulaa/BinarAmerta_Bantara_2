# %%
import pandas as pd

# %%
df = pd.read_csv('/content/Twitter_Emotion_Dataset.csv')
df
# Out:
#         label                                              tweet
# 0       anger  Soal jln Jatibaru,polisi tdk bs GERTAK gubernu...
# 1       anger  Sesama cewe lho (kayaknya), harusnya bisa lebi...
# 2       happy  Kepingin gudeg mbarek Bu hj. Amad Foto dari go...
# 3       anger  Jln Jatibaru,bagian dari wilayah Tn Abang.Peng...
# 4       happy  Sharing pengalaman aja, kemarin jam 18.00 bata...
# ...       ...                                                ...
# 4396     love  Tahukah kamu, bahwa saat itu papa memejamkan m...
# 4397     fear  Sulitnya menetapkan Calon Wapresnya Jokowi di ...
# 4398    anger  5. masa depannya nggak jelas. lha iya, gimana ...
# 4399    happy  [USERNAME] dulu beneran ada mahasiswa Teknik U...
# 4400  sadness  Ya Allah, hanya Engkau yang mengetahui rasa sa...
#
# [4401 rows x 2 columns]

# %%
df['label'].value_counts()
# Out:
# label
# anger      1101
# happy      1017
# sadness     997
# fear        649
# love        637
# Name: count, dtype: int64

# %%
df.isna().sum()
# Out:
# label    0
# tweet    0
# dtype: int64

# %%
import pandas as pd

# Misal df kamu sudah ada
# Kalau belum ada:
# df = pd.read_csv('nama_file.csv')

# Cek data dikit
print(df.head())

# Fungsi untuk mengkategorikan
def categorize_emotion(label):
    if label in ['happy', 'love']:
        return 'Positif'
    else:
        return 'Negatif'

# Terapkan fungsi ke kolom 'label'
df['label'] = df['label'].apply(categorize_emotion)

# Cek hasil
print(df['label'].value_counts())
print(df.head())
# Out:
#    label                                              tweet
# 0  anger  Soal jln Jatibaru,polisi tdk bs GERTAK gubernu...
# 1  anger  Sesama cewe lho (kayaknya), harusnya bisa lebi...
# 2  happy  Kepingin gudeg mbarek Bu hj. Amad Foto dari go...
# 3  anger  Jln Jatibaru,bagian dari wilayah Tn Abang.Peng...
# 4  happy  Sharing pengalaman aja, kemarin jam 18.00 bata...
# label
# Negatif    2747
# Positif    1654
# Name: count, dtype: int64
#      label                                              tweet
# 0  Negatif  Soal jln Jatibaru,polisi tdk bs GERTAK gubernu...
# 1  Negatif  Sesama cewe lho (kayaknya), harusnya bisa lebi...
# 2  Positif  Kepingin gudeg mbarek Bu hj. Amad Foto dari go...
# 3  Negatif  Jln Jatibaru,bagian dari wilayah Tn Abang.Peng...
# 4  Positif  Sharing pengalaman aja, kemarin jam 18.00 bata...

# %%
df
# Out:
#         label                                              tweet
# 0     Negatif  Soal jln Jatibaru,polisi tdk bs GERTAK gubernu...
# 1     Negatif  Sesama cewe lho (kayaknya), harusnya bisa lebi...
# 2     Positif  Kepingin gudeg mbarek Bu hj. Amad Foto dari go...
# 3     Negatif  Jln Jatibaru,bagian dari wilayah Tn Abang.Peng...
# 4     Positif  Sharing pengalaman aja, kemarin jam 18.00 bata...
# ...       ...                                                ...
# 4396  Positif  Tahukah kamu, bahwa saat itu papa memejamkan m...
# 4397  Negatif  Sulitnya menetapkan Calon Wapresnya Jokowi di ...
# 4398  Negatif  5. masa depannya nggak jelas. lha iya, gimana ...
# 4399  Positif  [USERNAME] dulu beneran ada mahasiswa Teknik U...
# 4400  Negatif  Ya Allah, hanya Engkau yang mengetahui rasa sa...
#
# [4401 rows x 2 columns]

# %%
df['label'].value_counts()
# Out:
# label
# Negatif    2747
# Positif    1654
# Name: count, dtype: int64

# %% [markdown]
# #pre-processing

# %%
df['tweet']=df['tweet'].str.lower()
df
# Out:
#         label                                              tweet
# 0     Negatif  soal jln jatibaru,polisi tdk bs gertak gubernu...
# 1     Negatif  sesama cewe lho (kayaknya), harusnya bisa lebi...
# 2     Positif  kepingin gudeg mbarek bu hj. amad foto dari go...
# 3     Negatif  jln jatibaru,bagian dari wilayah tn abang.peng...
# 4     Positif  sharing pengalaman aja, kemarin jam 18.00 bata...
# ...       ...                                                ...
# 4396  Positif  tahukah kamu, bahwa saat itu papa memejamkan m...
# 4397  Negatif  sulitnya menetapkan calon wapresnya jokowi di ...
# 4398  Negatif  5. masa depannya nggak jelas. lha iya, gimana ...
# 4399  Positif  [username] dulu beneran ada mahasiswa teknik u...
# 4400  Negatif  ya allah, hanya engkau yang mengetahui rasa sa...
#
# [4401 rows x 2 columns]

# %%
import re
import string
import unicodedata
import emoji
import pandas as pd

# Fungsi untuk membersihkan tweet
def clean_tweet(tweet):
    tweet = re.sub("@[A-Za-z0-9_]+", "", tweet)
    tweet = re.sub(r'([a-zA-Z])([A-Z])', r'\1 \2', tweet)
    # Hapus URL
    tweet = re.sub(r"(?:\@|http?\://|https?\://|www)\S+", "", tweet)
    tweet = re.sub(r'(.)\1+', r'\1', tweet)
    # Hapus angka
    tweet = re.sub(r"\d+", "", tweet)

    # Hapus emoji
    tweet = ''.join(c for c in tweet if not emoji.is_emoji(c))

    # Hapus tanda baca
    tweet = re.sub(r'([a-zA-Z])(\.|,|\?|!|;|:)([a-zA-Z])', r'\1 \3', tweet)
    tweet = tweet.translate(str.maketrans("", "", string.punctuation))

    # Hapus karakter yang tidak diinginkan (ekstra spasi)
    tweet = " ".join(tweet.split())

    # Normalisasi teks untuk menangani karakter asing
    tweet = unicodedata.normalize('NFKD', tweet).encode('ascii', 'ignore').decode('utf-8', 'ignore')

    # Hapus simbol seperti "#" atau "_"
 # Hapus simbol seperti "#" atau "_"
    tweet = tweet.replace("#", "").replace("_", " ")
    return tweet

df['tweet']=df['tweet'].apply(clean_tweet)
df
# Out:
#         label                                              tweet
# 0     Negatif  soal jln jatibaru polisi tdk bs gertak gubernu...
# 1     Negatif  sesama cewe lho kayaknya harusnya bisa lebih r...
# 2     Positif  kepingin gudeg mbarek bu hj amad foto dari gog...
# 3     Negatif  jln jatibaru bagian dari wilayah tn abang peng...
# 4     Positif  sharing pengalaman aja kemarin jam batalin tik...
# ...       ...                                                ...
# 4396  Positif  tahukah kamu bahwa sat itu papa memejamkan mat...
# 4397  Negatif  sulitnya menetapkan calon wapresnya jokowi di ...
# 4398  Negatif  masa depanya ngak jelas lha iya gimana mau jel...
# 4399  Positif  username dulu beneran ada mahasiswa teknik ui ...
# 4400  Negatif  ya alah hanya engkau yang mengetahui rasa saki...
#
# [4401 rows x 2 columns]

# %%
df.to_csv('pre-processing hackaton.csv', index=False)

# %%
# !pip install emoji

# %%
import pandas as pd
import json


# Membaca file txt yang berisi data JSON
def txt_to_csv(txt_file, csv_file):
    try:
        # Membaca isi file TXT
        with open(txt_file, 'r', encoding='utf-8') as file:
            content = file.read()

        # Mengonversi string JSON ke dictionary Python
        slang_dict = json.loads(content)

        # Mengonversi dictionary ke DataFrame
        df = pd.DataFrame(list(slang_dict.items()), columns=['Slang', 'Padanan'])

        # Menyimpan DataFrame ke file CSV
        df.to_csv(csv_file, index=False)

        print(f"Data berhasil disalin ke {csv_file}")

    except FileNotFoundError:
        print(f"File {txt_file} tidak ditemukan.")
    except Exception as e:
        print(f"Terjadi kesalahan: {e}")

# Contoh penggunaan
txt_to_csv('combined_slang_words (1).txt', 'slang dict.csv')
# Out:
# Data berhasil disalin ke slang dict.csv

# %%
slang=pd.read_csv('/content/new_kamusalay.csv',encoding='latin-1')
slang
# Out:
#       anakjakartaasikasik           anak jakarta asyik asyik
# 0            pakcikdahtua                  pak cik sudah tua
# 1          pakcikmudalagi                  pak cik muda lagi
# 2             t3tapjokowi                       tetap jokowi
# 3                      3x                          tiga kali
# 4                  aamiin                               amin
# ...                   ...                                ...
# 15161           mendikbud  menteri pendidikan dan kebudayaan
# 15162              mendag                menteri perdagangan
# 15163             menaker               menteri tenaga kerja
# 15164            memetwit                            mentwit
# 15165            megangin                           memegang
#
# [15166 rows x 2 columns]

# %%
def slang_to_formal(text, slang_dict):
    text = str(text) # Convert the Series object to a string
    words = text.split()
    formal_words = [slang_dict.get(word, word) for word in words]
    return " ".join(formal_words)
def load_slang_dict_from_csv(csv_file):
    # Load file CSV menjadi DataFrame
    df = pd.read_csv(csv_file,encoding='latin-1')
    # Pastikan kolom benar dan buat kamus slang-to-formal
    if 'anakjakartaasikasik' in df.columns and 'anak jakarta asyik asyik' in df.columns:
        slang_dict = dict(zip(df['anakjakartaasikasik'], df['anak jakarta asyik asyik']))
        return slang_dict
    else:
        raise ValueError("Kolom 'aamiin' dan 'amin' tidak ditemukan dalam file CSV")

slang_dict = load_slang_dict_from_csv('/content/new_kamusalay.csv')
df['tweet'] = df['tweet'].apply(lambda x: slang_to_formal(x, slang_dict))
df
# Out:
#         label                                              tweet
# 0     Negatif  soal jalan jatibaru polisi tidak bisa gertak g...
# 1     Negatif  sesama cewek lo kayaknya harusnya bisa lebih r...
# 2     Positif  ingin gudeg mbarek bu hj amat foto dari google...
# 3     Negatif  jalan jatibaru bagian dari wilayah tn abang pe...
# 4     Positif  sharing pengalaman saja kemarin jam batalin ti...
# ...       ...                                                ...
# 4396  Positif  tahukah kamu bahwa sat itu papa memejamkan mat...
# 4397  Negatif  sulitnya menetapkan calon wakil presidennya jo...
# 4398  Negatif  masa depanya tidak jelas lah iya bagaimana mau...
# 4399  Positif  nama pengguna dulu benaran ada mahasiswa tekni...
# 4400  Negatif  ya alah hanya engkau yang mengetahui rasa saki...
#
# [4401 rows x 2 columns]

# %%
from nltk.tokenize import word_tokenize
def tokenize(text):
    text = word_tokenize(text)
    return text

df['tokenize_text']= df['tweet'].apply(tokenize)
dftoken = df
df
# Out:
#         label                                              tweet  \
# 0     Negatif  soal jalan jatibaru polisi tidak bisa gertak g...
# 1     Negatif  sesama cewek lo kayaknya harusnya bisa lebih r...
# 2     Positif  ingin gudeg mbarek bu hj amat foto dari google...
# 3     Negatif  jalan jatibaru bagian dari wilayah tn abang pe...
# 4     Positif  sharing pengalaman saja kemarin jam batalin ti...
# ...       ...                                                ...
# 4396  Positif  tahukah kamu bahwa sat itu papa memejamkan mat...
# 4397  Negatif  sulitnya menetapkan calon wakil presidennya jo...
# 4398  Negatif  masa depanya tidak jelas lah iya bagaimana mau...
# 4399  Positif  nama pengguna dulu benaran ada mahasiswa tekni...
# 4400  Negatif  ya alah hanya engkau yang mengetahui rasa saki...
#
#                                           tokenize_text
# 0     [soal, jalan, jatibaru, polisi, tidak, bisa, g...
# 1     [sesama, cewek, lo, kayaknya, harusnya, bisa, ...
# ...

# %%
import nltk

# Clear NLTK cache
nltk.data.path = ['/root/nltk_data']

# Re-download 'punkt' and other required packages
nltk.download('punkt', download_dir='/root/nltk_data')
nltk.download('punkt_tab', download_dir='/root/nltk_data')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
# !pip install Sastrawi

# %%
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# Buat objek stopword remover
factory = StopWordRemoverFactory()
stopword_remover = factory.create_stop_word_remover()

# Definisikan fungsi untuk menghapus stopword
def remove_stopwords(text):
    if isinstance(text, list):  # Jika input berupa list token
        text = " ".join(text)
    elif not isinstance(text, str):  # Tangani input yang bukan string
        return ""
    text = stopword_remover.remove(text)  # Hapus stopword
    return text.split()  # Kembalikan dalam bentuk list token
dftoken['stop removal text']= dftoken['tokenize_text'].apply(remove_stopwords)
mcts = dftoken #menyatu-clean-tokenize-stopwords
mcts
# Out:
#         label                                              tweet  \
# 0     Negatif  soal jalan jatibaru polisi tidak bisa gertak g...
# 1     Negatif  sesama cewek lo kayaknya harusnya bisa lebih r...
# 2     Positif  ingin gudeg mbarek bu hj amat foto dari google...
# 3     Negatif  jalan jatibaru bagian dari wilayah tn abang pe...
# 4     Positif  sharing pengalaman saja kemarin jam batalin ti...
# ...       ...                                                ...
# 4396  Positif  tahukah kamu bahwa sat itu papa memejamkan mat...
# 4397  Negatif  sulitnya menetapkan calon wakil presidennya jo...
# 4398  Negatif  masa depanya tidak jelas lah iya bagaimana mau...
# 4399  Positif  nama pengguna dulu benaran ada mahasiswa tekni...
# 4400  Negatif  ya alah hanya engkau yang mengetahui rasa saki...
#
#                                           tokenize_text  \
# 0     [soal, jalan, jatibaru, polisi, tidak, bisa, g...
# 1     [sesama, cewek, lo, kayaknya, harusnya, bisa, ...
# ...

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

factory = StemmerFactory()
# Create a stemmer object using the factory
stemmer = factory.create_stemmer()

def stem_text(text):
    stemmed_tokens = [stemmer.stem(token) for token in text]
    return ' '.join(stemmed_tokens)

mcts['stemmed_text'] = mcts['stop removal text'].apply(stem_text)
mctss = mcts #menyatu-clean-toknize-stopwords-stemming
mctss
# Out:
#         label                                              tweet  \
# 0     Negatif  soal jalan jatibaru polisi tidak bisa gertak g...
# 1     Negatif  sesama cewek lo kayaknya harusnya bisa lebih r...
# 2     Positif  ingin gudeg mbarek bu hj amat foto dari google...
# 3     Negatif  jalan jatibaru bagian dari wilayah tn abang pe...
# 4     Positif  sharing pengalaman saja kemarin jam batalin ti...
# ...       ...                                                ...
# 4396  Positif  tahukah kamu bahwa sat itu papa memejamkan mat...
# 4397  Negatif  sulitnya menetapkan calon wakil presidennya jo...
# 4398  Negatif  masa depanya tidak jelas lah iya bagaimana mau...
# 4399  Positif  nama pengguna dulu benaran ada mahasiswa tekni...
# 4400  Negatif  ya alah hanya engkau yang mengetahui rasa saki...
#
#                                           tokenize_text  \
# 0     [soal, jalan, jatibaru, polisi, tidak, bisa, g...
# 1     [sesama, cewek, lo, kayaknya, harusnya, bisa, ...
# ...

# %% [markdown]
# #Modeling

# %%
import pandas as pd

data = pd.read_csv('/content/clean hack.csv')
data
# Out:
#       Unnamed: 0    label                                              tweet  \
# 0              0  Negatif  soal jalan jatibaru polisi tidak bisa gertak g...
# 1              1  Negatif  sesama cewek lo kayaknya harusnya bisa lebih r...
# 2              2  Positif  ingin gudeg mbarek bu hj amat foto dari google...
# 3              3  Negatif  jalan jatibaru bagian dari wilayah tn abang pe...
# 4              4  Positif  sharing pengalaman saja kemarin jam batalin ti...
# ...          ...      ...                                                ...
# 4396        4396  Positif  tahukah kamu bahwa sat itu papa memejamkan mat...
# 4397        4397  Negatif  sulitnya menetapkan calon wakil presidennya jo...
# 4398        4398  Negatif  masa depanya tidak jelas lah iya bagaimana mau...
# 4399        4399  Positif  nama pengguna dulu benaran ada mahasiswa tekni...
# 4400        4400  Negatif  ya alah hanya engkau yang mengetahui rasa saki...
#
# ...

# %%
data['label'].value_counts()
# Out:
# label
# Negatif    2747
# Positif    1654
# Name: count, dtype: int64

# %%
import joblib
from imblearn.over_sampling import SMOTE
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import LabelEncoder
import pandas as pd

# Misalnya, data yang sudah dipreprocessing dan siap digunakan
X = data['stemmed_text']
y = data['label']

# Encoding labels from string to numeric
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)  # Mengonversi 'Negatif', 'Positif' menjadi 0, 1

# TF-IDF Vectorization untuk mengubah teks menjadi fitur numerik
vectorizer = TfidfVectorizer()
X_tfidf = vectorizer.fit_transform(X).toarray()  # Mengubah teks menjadi array numerik

# Membagi data menjadi train dan test set
X_train, X_test, y_train, y_test = train_test_split(X_tfidf, y_encoded, stratify=y_encoded, test_size=0.2, random_state=45)

# Mengaplikasikan SMOTE untuk oversampling data minoritas pada data pelatihan
smote = SMOTE(random_state=45)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# Melatih model Multinomial Naive Bayes
mnb = MultinomialNB()
mnb.fit(X_train_resampled, y_train_resampled)

# Simpan model dan vectorizer
joblib.dump(mnb, 'model_multinomial_nb.pkl')  # Menyimpan model
joblib.dump(vectorizer, 'vectorizer.pkl')  # Menyimpan vectorizer

# Simpan model dan vectorizer ke dalam file
print("Model dan vectorizer disimpan!")

# Prediksi dengan input teks
def predict_sentiment(text_input):
    # Load model dan vectorizer
    model = joblib.load('model_multinomial_nb.pkl')
    vectorizer = joblib.load('vectorizer.pkl')

    # Transformasi teks input menggunakan vectorizer
    text_tfidf = vectorizer.transform([text_input]).toarray()

    # Prediksi menggunakan model
    prediction = model.predict(text_tfidf)

    # Dekode hasil prediksi ke label asli (Positif / Negatif)
    predicted_label = label_encoder.inverse_transform(prediction)

    return predicted_label[0]

# Test prediksi input teks
text_input = input("Masukkan teks untuk prediksi (Positif/Negatif): ")
predicted_sentiment = predict_sentiment(text_input)

print(f"Hasil prediksi: {predicted_sentiment}")
# Out:
# Model dan vectorizer disimpan!
# Masukkan teks untuk prediksi (Positif/Negatif): gusur aja tanahnya, orang gakepakai kok!
# Hasil prediksi: Negatif
